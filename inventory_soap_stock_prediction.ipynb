# %%
import csv
import random
from datetime import date, timedelta  # Import necessary classes from datetime

# Define the date range for June 2024
start_date = date(year=2024, month=6, day=1)
end_date = date(year=2024, month=6, day=30)

# Create the CSV file
with open('daily_qty.csv', 'w', newline='') as csvfile:
  # Create a CSV writer object
  writer = csv.writer(csvfile)

  # Write the header row
  writer.writerow(['date', 'qty'])

  # Generate and write data for each day in June
  for day in range((end_date - start_date).days + 1):
    date = start_date + timedelta(days=day)  # Add days using timedelta
    qty = random.randint(1, 10)
    writer.writerow([date.strftime('%Y-%m-%d'), qty])

print("CSV file created successfully: daily_qty.csv")
# Out:
# CSV file created successfully: daily_qty.csv

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 1, 31)
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam'},
    {'Item_Code': 'A2', 'Brand': 'LUX'},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue'},
    {'Item_Code': 'A4', 'Brand': 'Cinthol'},
    {'Item_Code': 'A5', 'Brand': 'Dove'},
    {'Item_Code': 'A6', 'Brand': 'Medimix'}
]
unit_price = 10

# List to store dataset
data = []

# Generate data for each day
current_date = start_date
while current_date <= end_date:
    for customer in customers:
        for item in items:
            qty = random.randint(1, 10)
            total_price = qty * unit_price
            data.append([
                'sales',
                current_date.strftime('%d-%b-%y'),
                customer,
                item['Item_Code'],
                item['Brand'],
                qty,
                unit_price,
                total_price
            ])
    current_date += timedelta(days=1)

# Create DataFrame
df = pd.DataFrame(data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price'])

# Save to CSV
df.to_csv('january_sales_data.csv', index=False)
print('created database')
# Out:
# created database

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 12, 31)
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam'},
    {'Item_Code': 'A2', 'Brand': 'LUX'},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue'},
    {'Item_Code': 'A4', 'Brand': 'Cinthol'},
    {'Item_Code': 'A5', 'Brand': 'Dove'},
    {'Item_Code': 'A6', 'Brand': 'Medimix'}
]
unit_price = 10
purchase_qty = 2500

# List to store dataset
data = []

# Generate data for each day
current_date = start_date
while current_date <= end_date:
    for customer in customers:
        for item in items:
            qty = random.randint(1, 10)
            total_price = qty * unit_price
            data.append([
                'sales',
                current_date.strftime('%d-%b-%y'),
                customer,
                item['Item_Code'],
                item['Brand'],
                qty,
                unit_price,
                total_price
            ])
    # Add purchases at the end of each month
    if current_date.day == (current_date + timedelta(days=1)).day:
        for item in items:
            total_price = purchase_qty * unit_price
            data.append([
                'purchase',
                current_date.strftime('%d-%b-%y'),
                'Vendor',
                item['Item_Code'],
                item['Brand'],
                purchase_qty,
                unit_price,
                total_price
            ])
    current_date += timedelta(days=1)

# Create DataFrame
df = pd.DataFrame(data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price'])

# Save to CSV
csv_path = 'full_years_sales_purchases_data.csv'
df.to_csv(csv_path, index=False)

csv_path
# Out:
# 'full_years_sales_purchases_data.csv'

# %%
import pandas as pd 
df=pd.read_csv('full_years_sales_purchases_data.csv')
df.head()
# Out:
#   Transaction       Date Customer Item_Code        Brand  Qty  Unit_Price  \
# 0       sales  01-Jan-23       C1        A1        Hamam    2          10
# 1       sales  01-Jan-23       C1        A2          LUX   10          10
# 2       sales  01-Jan-23       C1        A3  Park Avenue    9          10
# 3       sales  01-Jan-23       C1        A4      Cinthol    3          10
# 4       sales  01-Jan-23       C1        A5         Dove   10          10
#
#    Total_Price
# 0           20
# 1          100
# 2           90
# 3           30
# 4          100

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 12, 31)
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam'},
    {'Item_Code': 'A2', 'Brand': 'LUX'},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue'},
    {'Item_Code': 'A4', 'Brand': 'Cinthol'},
    {'Item_Code': 'A5', 'Brand': 'Dove'},
    {'Item_Code': 'A6', 'Brand': 'Medimix'}
]
unit_price = 10
purchase_qty = 2500

# List to store dataset
data = []

# Generate data for each day
current_date = start_date
while current_date <= end_date:
    for customer in customers:
        for item in items:
            qty = random.randint(1, 10)
            total_price = qty * unit_price
            data.append([
                'sales',
                current_date.strftime('%d-%b-%y'),
                customer,
                item['Item_Code'],
                item['Brand'],
                qty,
                unit_price,
                total_price
            ])
    # Add purchases at the end of each month
    if current_date.day == (current_date + timedelta(days=1)).day:
        for item in items:
            total_price = purchase_qty * unit_price
            data.append([
                'purchase',
                current_date.strftime('%d-%b-%y'),
                'Vendor',
                item['Item_Code'],
                item['Brand'],
                purchase_qty,
                unit_price,
                total_price
            ])
    current_date += timedelta(days=1)

# Create DataFrame
df = pd.DataFrame(data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price'])

# Save to CSV
csv_path = 'full_years_sales_purchases_data.csv'
df.to_csv(csv_path, index=False)

csv_path
# Out:
# 'full_years_sales_purchases_data.csv'

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 12, 31)
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam', 'Initial_Stock': 1000},
    {'Item_Code': 'A2', 'Brand': 'LUX', 'Initial_Stock': 1000},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue', 'Initial_Stock': 1000},
    {'Item_Code': 'A4', 'Brand': 'Cinthol', 'Initial_Stock': 1000},
    {'Item_Code': 'A5', 'Brand': 'Dove', 'Initial_Stock': 1000},
    {'Item_Code': 'A6', 'Brand': 'Medimix', 'Initial_Stock': 1000}
]
unit_price = 10
purchase_qty = 2500

# Dictionary to track stock levels
stock_levels = {item['Item_Code']: item['Initial_Stock'] for item in items}

# List to store dataset
data = []

# Generate data for each day
current_date = start_date
while current_date <= end_date:
    for customer in customers:
        for item in items:
            if current_date.month in [3, 4, 5]:  # Increase qty in summer months
                qty = random.randint(5, 15)
            else:
                qty = random.randint(1, 10)
            total_price = qty * unit_price
            stock_levels[item['Item_Code']] -= qty
            data.append([
                'sales',
                current_date.strftime('%d-%b-%y'),
                customer,
                item['Item_Code'],
                item['Brand'],
                qty,
                unit_price,
                total_price,
                stock_levels[item['Item_Code']]
            ])
    # Add purchases at the end of each month
    next_day = current_date + timedelta(days=1)
    if next_day.month != current_date.month:
        for item in items:
            total_price = purchase_qty * unit_price
            stock_levels[item['Item_Code']] += purchase_qty
            data.append([
                'purchase',
                current_date.strftime('%d-%b-%y'),
                'Vendor',
                item['Item_Code'],
                item['Brand'],
                purchase_qty,
                unit_price,
                total_price,
                stock_levels[item['Item_Code']]
            ])
    current_date += timedelta(days=1)

# Create DataFrame
df_with_stock = pd.DataFrame(data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price', 'Stock_Remaining'])

# Save to CSV
csv_path_with_stock = 'full_years_sales_purchases_with_stock_data.csv'
df_with_stock.to_csv(csv_path_with_stock, index=False)
df_with_stock.head()
# Out:
#   Transaction       Date Customer Item_Code        Brand  Qty  Unit_Price  \
# 0       sales  01-Jan-23       C1        A1        Hamam    8          10
# 1       sales  01-Jan-23       C1        A2          LUX    6          10
# 2       sales  01-Jan-23       C1        A3  Park Avenue    8          10
# 3       sales  01-Jan-23       C1        A4      Cinthol    9          10
# 4       sales  01-Jan-23       C1        A5         Dove    9          10
#
#    Total_Price  Stock_Remaining
# 0           80              992
# 1           60              994
# 2           80              992
# 3           90              991
# 4           90              991

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 12, 31)
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam', 'Initial_Stock': 2000},
    {'Item_Code': 'A2', 'Brand': 'LUX', 'Initial_Stock': 2000},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue', 'Initial_Stock': 2000},
    {'Item_Code': 'A4', 'Brand': 'Cinthol', 'Initial_Stock': 2000},
    {'Item_Code': 'A5', 'Brand': 'Dove', 'Initial_Stock': 2000},
    {'Item_Code': 'A6', 'Brand': 'Medimix', 'Initial_Stock': 2000}
]
unit_price = 10
purchase_qty_regular = 2100
purchase_qty_summer = 2200

# Dictionary to track stock levels
stock_levels = {item['Item_Code']: item['Initial_Stock'] for item in items}

# List to store dataset
data = []

# Generate data for each day
current_date = start_date
while current_date <= end_date:
    for customer in customers:
        for item in items:
            if current_date.month in [3, 4, 5]:  # Increase qty in summer months
                qty = random.randint(5, 15)
            else:
                qty = random.randint(1, 10)
            total_price = qty * unit_price
            stock_levels[item['Item_Code']] -= qty
            stock_levels[item['Item_Code']] = max(0, stock_levels[item['Item_Code']])  # Ensure stock is not negative
            data.append([
                'sales',
                current_date.strftime('%d-%b-%y'),
                customer,
                item['Item_Code'],
                item['Brand'],
                qty,
                unit_price,
                total_price,
                stock_levels[item['Item_Code']]
            ])
    # Add purchases at the end of each month
    next_day = current_date + timedelta(days=1)
    if next_day.month != current_date.month:
        for item in items:
            if current_date.month in [2, 3, 4, 5]:  # March, April, May, and June (considering Feb end for March purchases)
                total_price = purchase_qty_summer * unit_price
                stock_levels[item['Item_Code']] += purchase_qty_summer
            else:
                total_price = purchase_qty_regular * unit_price
                stock_levels[item['Item_Code']] += purchase_qty_regular
            data.append([
                'purchase',
                current_date.strftime('%d-%b-%y'),
                'Vendor',
                item['Item_Code'],
                item['Brand'],
                purchase_qty_summer if current_date.month in [2, 3, 4, 5] else purchase_qty_regular,
                unit_price,
                total_price,
                stock_levels[item['Item_Code']]
            ])
    current_date += timedelta(days=1)

# Create DataFrame
df_with_stock = pd.DataFrame(data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price', 'Stock_Remaining'])

# Save to CSV
csv_path_with_stock = 'full_years_sales_purchases_with_stock_data.csv'
df_with_stock.to_csv(csv_path_with_stock, index=False)
print(df_with_stock.head())

# Find stock shortages
shortages = df_with_stock[df_with_stock['Stock_Remaining'] == 0]
print("Stock shortages:")
print(shortages)

# Predict future stock shortages based on the same pattern
def predict_stock_shortages(df, start_date, end_date):
    future_data = []
    future_stock_levels = stock_levels.copy()
    current_date = start_date

    while current_date <= end_date:
        for customer in customers:
            for item in items:
                if current_date.month in [3, 4, 5]:  # Increase qty in summer months
                    qty = random.randint(5, 15)
                else:
                    qty = random.randint(1, 10)
                total_price = qty * unit_price
                future_stock_levels[item['Item_Code']] -= qty
                future_stock_levels[item['Item_Code']] = max(0, future_stock_levels[item['Item_Code']])  # Ensure stock is not negative
                future_data.append([
                    'sales',
                    current_date.strftime('%d-%b-%y'),
                    customer,
                    item['Item_Code'],
                    item['Brand'],
                    qty,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        # Add purchases at the end of each month
        next_day = current_date + timedelta(days=1)
        if next_day.month != current_date.month:
            for item in items:
                if current_date.month in [2, 3, 4, 5]:  # March, April, May, and June (considering Feb end for March purchases)
                    total_price = purchase_qty_summer * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_summer
                else:
                    total_price = purchase_qty_regular * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_regular
                future_data.append([
                    'purchase',
                    current_date.strftime('%d-%b-%y'),
                    'Vendor',
                    item['Item_Code'],
                    item['Brand'],
                    purchase_qty_summer if current_date.month in [2, 3, 4, 5] else purchase_qty_regular,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        current_date += timedelta(days=1)
    
    df_future = pd.DataFrame(future_data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price', 'Stock_Remaining'])
    future_shortages = df_future[df_future['Stock_Remaining'] == 0]
    return future_shortages

# Predict stock shortages for the next year

future_start_date = datetime(2025, 1, 1)
future_end_date = datetime(2025, 12, 31)
future_shortages = predict_stock_shortages(df_with_stock, future_start_date, future_end_date)
print("Predicted future stock shortages:")
print(future_shortages)
# Out:
#   Transaction       Date Customer Item_Code        Brand  Qty  Unit_Price  \
# 0       sales  01-Jan-23       C1        A1        Hamam    2          10
# 1       sales  01-Jan-23       C1        A2          LUX    5          10
# 2       sales  01-Jan-23       C1        A3  Park Avenue    7          10
# 3       sales  01-Jan-23       C1        A4      Cinthol    4          10
# 4       sales  01-Jan-23       C1        A5         Dove    5          10
#
#    Total_Price  Stock_Remaining
# 0           20             1998
# 1           50             1995
# 2           70             1993
# 3           40             1996
# 4           50             1995
# Stock shortages:
#      Transaction       Date Customer Item_Code        Brand  Qty  Unit_Price  \
# 6450       sales  30-Apr-23       C2        A1        Hamam   15          10
# 6456       sales  30-Apr-23       C3        A1        Hamam    9          10
# ...

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 12, 31)
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam', 'Initial_Stock': 2000},
    {'Item_Code': 'A2', 'Brand': 'LUX', 'Initial_Stock': 2000},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue', 'Initial_Stock': 2000},
    {'Item_Code': 'A4', 'Brand': 'Cinthol', 'Initial_Stock': 2000},
    {'Item_Code': 'A5', 'Brand': 'Dove', 'Initial_Stock': 2000},
    {'Item_Code': 'A6', 'Brand': 'Medimix', 'Initial_Stock': 2000}
]
unit_price = 10
purchase_qty_regular = 2100
purchase_qty_summer = 2300

# Dictionary to track stock levels
stock_levels = {item['Item_Code']: item['Initial_Stock'] for item in items}

# List to store dataset
data = []

# Generate data for each day
current_date = start_date
while current_date <= end_date:
    for customer in customers:
        for item in items:
            if current_date.month in [3, 4, 5]:  # Increase qty in summer months
                qty = random.randint(5, 15)
            else:
                qty = random.randint(1, 10)
            total_price = qty * unit_price
            stock_levels[item['Item_Code']] -= qty
            stock_levels[item['Item_Code']] = max(0, stock_levels[item['Item_Code']])  # Ensure stock is not negative
            data.append([
                'sales',
                current_date.strftime('%d-%b-%y'),
                customer,
                item['Item_Code'],
                item['Brand'],
                qty,
                unit_price,
                total_price,
                stock_levels[item['Item_Code']]
            ])
    # Add purchases at the end of each month
    next_day = current_date + timedelta(days=1)
    if next_day.month != current_date.month:
        for item in items:
            if current_date.month in [2, 3, 4, 5]:  # March, April, May, and June (considering Feb end for March purchases)
                total_price = purchase_qty_summer * unit_price
                stock_levels[item['Item_Code']] += purchase_qty_summer
            else:
                total_price = purchase_qty_regular * unit_price
                stock_levels[item['Item_Code']] += purchase_qty_regular
            data.append([
                'purchase',
                current_date.strftime('%d-%b-%y'),
                'Vendor',
                item['Item_Code'],
                item['Brand'],
                purchase_qty_summer if current_date.month in [2, 3, 4, 5] else purchase_qty_regular,
                unit_price,
                total_price,
                stock_levels[item['Item_Code']]
            ])
    current_date += timedelta(days=1)

# Create DataFrame
df_with_stock = pd.DataFrame(data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price', 'Stock_Remaining'])

# Save to CSV
csv_path_with_stock = 'full_years_sales_purchases_with_stock_data.csv'
df_with_stock.to_csv(csv_path_with_stock, index=False)
print(df_with_stock.head())

# Find stock shortages
shortages = df_with_stock[df_with_stock['Stock_Remaining'] == 0]
print("Stock shortages:")
print(shortages[['Date', 'Item_Code', 'Brand']])

# Predict future stock shortages based on the same pattern
def predict_stock_shortages(start_date, end_date):
    future_data = []
    future_stock_levels = stock_levels.copy()
    current_date = start_date
    future_shortages = []

    while current_date <= end_date:
        for customer in customers:
            for item in items:
                if current_date.month in [3, 4, 5]:  # Increase qty in summer months
                    qty = random.randint(5, 15)
                else:
                    qty = random.randint(1, 10)
                total_price = qty * unit_price
                future_stock_levels[item['Item_Code']] -= qty
                future_stock_levels[item['Item_Code']] = max(0, future_stock_levels[item['Item_Code']])  # Ensure stock is not negative
                future_data.append([
                    'sales',
                    current_date.strftime('%d-%b-%y'),
                    customer,
                    item['Item_Code'],
                    item['Brand'],
                    qty,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
                if future_stock_levels[item['Item_Code']] == 0:
                    future_shortages.append((current_date.strftime('%d-%b-%y'), item['Item_Code'], item['Brand']))
        # Add purchases at the end of each month
        next_day = current_date + timedelta(days=1)
        if next_day.month != current_date.month:
            for item in items:
                if current_date.month in [2, 3, 4, 5]:  # March, April, May, and June (considering Feb end for March purchases)
                    total_price = purchase_qty_summer * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_summer
                else:
                    total_price = purchase_qty_regular * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_regular
                future_data.append([
                    'purchase',
                    current_date.strftime('%d-%b-%y'),
                    'Vendor',
                    item['Item_Code'],
                    item['Brand'],
                    purchase_qty_summer if current_date.month in [2, 3, 4, 5] else purchase_qty_regular,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        current_date += timedelta(days=1)

    return future_shortages

# Predict stock shortages for the next year
future_start_date = datetime(2025, 1, 1)
future_end_date = datetime(2025, 12, 31)
future_shortages = predict_stock_shortages(future_start_date, future_end_date)
print("Predicted future stock shortages:")
for shortage in future_shortages:
    print(shortage)
# Out:
#   Transaction       Date Customer Item_Code        Brand  Qty  Unit_Price  \
# 0       sales  01-Jan-23       C1        A1        Hamam    4          10
# 1       sales  01-Jan-23       C1        A2          LUX    4          10
# 2       sales  01-Jan-23       C1        A3  Park Avenue    9          10
# 3       sales  01-Jan-23       C1        A4      Cinthol    8          10
# 4       sales  01-Jan-23       C1        A5         Dove    9          10
#
#    Total_Price  Stock_Remaining
# 0           40             1996
# 1           40             1996
# 2           90             1991
# 3           80             1992
# 4           90             1991
# Stock shortages:
#            Date Item_Code        Brand
# 8012  28-May-23        A3  Park Avenue
# 8018  29-May-23        A3  Park Avenue
# 8024  29-May-23        A3  Park Avenue
# 8025  29-May-23        A4      Cinthol
# 8030  29-May-23        A3  Park Avenue
# ...         ...       ...          ...
# ...

# %%
import pandas as pd

# Load the generated dataset
df_with_stock = pd.read_csv('full_years_sales_purchases_with_stock_data.csv')

# Find stock shortages
shortages = df_with_stock[df_with_stock['Stock_Remaining'] == 0]

# Select relevant columns for the shortages
shortages_details = shortages[['Date', 'Item_Code', 'Brand']]

shortages_details = shortages_details.drop_duplicates()

# Save the shortages details to a CSV file
shortages_csv_path = 'stock_shortages.csv'
shortages_details.to_csv(shortages_csv_path, index=False)

print("Stock shortages details saved to:", shortages_csv_path)
# Out:
# Stock shortages details saved to: stock_shortages.csv

# %%
import pandas as pd
df1=pd.read_csv("full_years_sales_purchases_with_stock_data.csv") 
# print(df1.head())
df2=df1.drop(columns=["Unit_Price","Total_Price"])
df2.to_csv("final_inventory_csv.csv")
df2.head()
# Out:
#   Transaction       Date Customer Item_Code        Brand  Qty  Stock_Remaining
# 0       sales  01-Jan-23       C1        A1        Hamam    4             1996
# 1       sales  01-Jan-23       C1        A2          LUX    4             1996
# 2       sales  01-Jan-23       C1        A3  Park Avenue    9             1991
# 3       sales  01-Jan-23       C1        A4      Cinthol    8             1992
# 4       sales  01-Jan-23       C1        A5         Dove    9             1991

# %%
shortage_df=pd.read_csv("stock_shortages.csv")
shortage_df.head(15)
# Out:
#          Date Item_Code        Brand
# 0   28-May-23        A3  Park Avenue
# 1   29-May-23        A3  Park Avenue
# 2   29-May-23        A4      Cinthol
# 3   29-May-23        A1        Hamam
# 4   30-May-23        A1        Hamam
# 5   30-May-23        A3  Park Avenue
# 6   30-May-23        A4      Cinthol
# 7   30-May-23        A5         Dove
# 8   30-May-23        A2          LUX
# 9   31-May-23        A1        Hamam
# 10  31-May-23        A2          LUX
# 11  31-May-23        A3  Park Avenue
# 12  31-May-23        A4      Cinthol
# 13  31-May-23        A5         Dove

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam', 'Initial_Stock': 2000},
    {'Item_Code': 'A2', 'Brand': 'LUX', 'Initial_Stock': 2000},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue', 'Initial_Stock': 2000},
    {'Item_Code': 'A4', 'Brand': 'Cinthol', 'Initial_Stock': 2000},
    {'Item_Code': 'A5', 'Brand': 'Dove', 'Initial_Stock': 2000},
    {'Item_Code': 'A6', 'Brand': 'Medimix', 'Initial_Stock': 2000}
]
unit_price = 10
purchase_qty_regular = 2000
purchase_qty_summer = 2200

# Dictionary to track stock levels
stock_levels = {item['Item_Code']: item['Initial_Stock'] for item in items}

# Predict future stock shortages based on the same pattern
def predict_stock_shortages(start_date, end_date):
    future_data = []
    future_stock_levels = stock_levels.copy()
    current_date = start_date

    while current_date <= end_date:
        for customer in customers:
            for item in items:
                if current_date.month in [3, 4, 5]:  # Increase qty in summer months
                    qty = random.randint(5, 15)
                else:
                    qty = random.randint(1, 10)
                total_price = qty * unit_price
                future_stock_levels[item['Item_Code']] -= qty
                future_stock_levels[item['Item_Code']] = max(0, future_stock_levels[item['Item_Code']])  # Ensure stock is not negative
                future_data.append([
                    'sales',
                    current_date.strftime('%d-%b-%y'),
                    customer,
                    item['Item_Code'],
                    item['Brand'],
                    qty,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        # Add purchases at the end of each month
        next_day = current_date + timedelta(days=1)
        if next_day.month != current_date.month:
            for item in items:
                if current_date.month in [2, 3, 4, 5]:  # March, April, May, and June (considering Feb end for March purchases)
                    total_price = purchase_qty_summer * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_summer
                else:
                    total_price = purchase_qty_regular * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_regular
                future_data.append([
                    'purchase',
                    current_date.strftime('%d-%b-%y'),
                    'Vendor',
                    item['Item_Code'],
                    item['Brand'],
                    purchase_qty_summer if current_date.month in [2, 3, 4, 5] else purchase_qty_regular,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        current_date += timedelta(days=1)
    
    df_future = pd.DataFrame(future_data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price', 'Stock_Remaining'])
    future_shortages = df_future[df_future['Stock_Remaining'] == 0]
    return future_shortages

# Predict stock shortages for the next year
future_start_date = datetime(2025, 1, 1)
future_end_date = datetime(2025, 12, 31)
future_shortages = predict_stock_shortages(future_start_date, future_end_date)

# Select relevant columns for the shortages
future_shortages_details = future_shortages[['Date', 'Item_Code', 'Brand']]

# Remove duplicate records
future_shortages_details = future_shortages_details.drop_duplicates()

# Save the predicted shortages details to a CSV file
future_shortages_csv_path = 'predicted_stock_shortages.csv'
future_shortages_details.to_csv(future_shortages_csv_path, index=False)

print("Predicted future stock shortages details saved to:", future_shortages_csv_path)
# Out:
# Predicted future stock shortages details saved to: predicted_stock_shortages.csv

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam', 'Initial_Stock': 2000},
    {'Item_Code': 'A2', 'Brand': 'LUX', 'Initial_Stock': 2000},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue', 'Initial_Stock': 2000},
    {'Item_Code': 'A4', 'Brand': 'Cinthol', 'Initial_Stock': 2000},
    {'Item_Code': 'A5', 'Brand': 'Dove', 'Initial_Stock': 2000},
    {'Item_Code': 'A6', 'Brand': 'Medimix', 'Initial_Stock': 2000}
]
unit_price = 10
purchase_qty_regular = 2100
purchase_qty_summer = 2200

# Dictionary to track stock levels
stock_levels = {item['Item_Code']: item['Initial_Stock'] for item in items}

# Predict future stock shortages based on the same pattern
def predict_stock_shortages(start_date, end_date):
    future_data = []
    future_stock_levels = stock_levels.copy()
    current_date = start_date

    while current_date <= end_date:
        for customer in customers:
            for item in items:
                if current_date.month in [3, 4, 5]:  # Increase qty in summer months
                    qty = random.randint(5, 15)
                else:
                    qty = random.randint(1, 10)
                total_price = qty * unit_price
                future_stock_levels[item['Item_Code']] -= qty
                future_stock_levels[item['Item_Code']] = max(0, future_stock_levels[item['Item_Code']])  # Ensure stock is not negative
                future_data.append([
                    'sales',
                    current_date.strftime('%d-%b-%y'),
                    customer,
                    item['Item_Code'],
                    item['Brand'],
                    qty,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        # Add purchases at the end of each month
        next_day = current_date + timedelta(days=1)
        if next_day.month != current_date.month:
            for item in items:
                if current_date.month in [2, 3, 4, 5]:  # March, April, May, and June (considering Feb end for March purchases)
                    total_price = purchase_qty_summer * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_summer
                else:
                    total_price = purchase_qty_regular * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_regular
                future_data.append([
                    'purchase',
                    current_date.strftime('%d-%b-%y'),
                    'Vendor',
                    item['Item_Code'],
                    item['Brand'],
                    purchase_qty_summer if current_date.month in [2, 3, 4, 5] else purchase_qty_regular,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        current_date += timedelta(days=1)
    
    df_future = pd.DataFrame(future_data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price', 'Stock_Remaining'])
    future_shortages = df_future[df_future['Stock_Remaining'] == 0]
    return future_shortages

# Predict stock shortages for the next year
future_start_date = datetime(2025, 1, 1)
future_end_date = datetime(2025, 12, 31)
future_shortages = predict_stock_shortages(future_start_date, future_end_date)

# Select relevant columns for the shortages and add remaining inventory column
future_shortages_details = future_shortages[['Date', 'Item_Code', 'Brand', 'Stock_Remaining']]

# Remove duplicate records
future_shortages_details = future_shortages_details.drop_duplicates()

# Save the predicted shortages details to a CSV file
future_shortages_csv_path = 'predicted_stock_shortages.csv'
future_shortages_details.to_csv(future_shortages_csv_path, index=False)

print("Predicted future stock shortages details saved to:", future_shortages_csv_path)
# Out:
# Predicted future stock shortages details saved to: predicted_stock_shortages.csv

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam', 'Initial_Stock': 2000},
    {'Item_Code': 'A2', 'Brand': 'LUX', 'Initial_Stock': 2000},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue', 'Initial_Stock': 2000},
    {'Item_Code': 'A4', 'Brand': 'Cinthol', 'Initial_Stock': 2000},
    {'Item_Code': 'A5', 'Brand': 'Dove', 'Initial_Stock': 2000},
    {'Item_Code': 'A6', 'Brand': 'Medimix', 'Initial_Stock': 2000}
]
unit_price = 10
purchase_qty_regular = 2100
purchase_qty_summer = 2200

# Dictionary to track stock levels
stock_levels = {item['Item_Code']: item['Initial_Stock'] for item in items}

# Predict future stock warnings based on the same pattern
def predict_stock_warnings(start_date, end_date):
    future_data = []
    future_stock_levels = stock_levels.copy()
    current_date = start_date

    while current_date <= end_date:
        for customer in customers:
            for item in items:
                if current_date.month in [3, 4, 5]:  # Increase qty in summer months
                    qty = random.randint(5, 15)
                else:
                    qty = random.randint(1, 10)
                total_price = qty * unit_price
                future_stock_levels[item['Item_Code']] -= qty
                future_stock_levels[item['Item_Code']] = max(0, future_stock_levels[item['Item_Code']])  # Ensure stock is not negative
                future_data.append([
                    'sales',
                    current_date.strftime('%d-%b-%y'),
                    customer,
                    item['Item_Code'],
                    item['Brand'],
                    qty,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        # Add purchases at the end of each month
        next_day = current_date + timedelta(days=1)
        if next_day.month != current_date.month:
            for item in items:
                if current_date.month in [2, 3, 4, 5]:  # March, April, May, and June (considering Feb end for March purchases)
                    total_price = purchase_qty_summer * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_summer
                else:
                    total_price = purchase_qty_regular * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_regular
                future_data.append([
                    'purchase',
                    current_date.strftime('%d-%b-%y'),
                    'Vendor',
                    item['Item_Code'],
                    item['Brand'],
                    purchase_qty_summer if current_date.month in [2, 3, 4, 5] else purchase_qty_regular,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        current_date += timedelta(days=1)
    
    df_future = pd.DataFrame(future_data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price', 'Stock_Remaining'])
    future_warnings = df_future[(df_future['Stock_Remaining'] <= 100) & (df_future['Stock_Remaining'] >= 0)]
    return future_warnings

# Predict stock warnings for the next year
future_start_date = datetime(2025, 1, 1)
future_end_date = datetime(2025, 12, 31)
future_warnings = predict_stock_warnings(future_start_date, future_end_date)

# Select relevant columns for the warnings and add remaining inventory column
future_warnings_details = future_warnings[['Date', 'Item_Code', 'Brand', 'Stock_Remaining']]

# Remove duplicate records
future_warnings_details = future_warnings_details.drop_duplicates()

# Save the predicted warnings details to a CSV file
future_warnings_csv_path = 'predicted_stock_warnings.csv'
future_warnings_details.to_csv(future_warnings_csv_path, index=False)

print("Predicted future stock warnings details saved to:", future_warnings_csv_path)
# Out:
# Predicted future stock warnings details saved to: predicted_stock_warnings.csv

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Constants
customers = ['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
items = [
    {'Item_Code': 'A1', 'Brand': 'Hamam', 'Initial_Stock': 2000},
    {'Item_Code': 'A2', 'Brand': 'LUX', 'Initial_Stock': 2000},
    {'Item_Code': 'A3', 'Brand': 'Park Avenue', 'Initial_Stock': 2000},
    {'Item_Code': 'A4', 'Brand': 'Cinthol', 'Initial_Stock': 2000},
    {'Item_Code': 'A5', 'Brand': 'Dove', 'Initial_Stock': 2000},
    {'Item_Code': 'A6', 'Brand': 'Medimix', 'Initial_Stock': 2000}
]
unit_price = 10
purchase_qty_regular = 2100
purchase_qty_summer = 2200

# Dictionary to track stock levels
stock_levels = {item['Item_Code']: item['Initial_Stock'] for item in items}

# Predict future stock warnings based on the same pattern
def predict_stock_warnings(start_date, end_date):
    future_data = []
    future_stock_levels = stock_levels.copy()
    current_date = start_date

    while current_date <= end_date:
        for customer in customers:
            for item in items:
                if current_date.month in [3, 4, 5]:  # Increase qty in summer months
                    qty = random.randint(5, 15)
                else:
                    qty = random.randint(1, 10)
                total_price = qty * unit_price
                future_stock_levels[item['Item_Code']] -= qty
                future_stock_levels[item['Item_Code']] = max(0, future_stock_levels[item['Item_Code']])  # Ensure stock is not negative
                future_data.append([
                    'sales',
                    current_date.strftime('%d-%b-%y'),
                    customer,
                    item['Item_Code'],
                    item['Brand'],
                    qty,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        # Add purchases at the end of each month
        next_day = current_date + timedelta(days=1)
        if next_day.month != current_date.month:
            for item in items:
                if current_date.month in [2, 3, 4, 5]:  # March, April, May, and June (considering Feb end for March purchases)
                    total_price = purchase_qty_summer * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_summer
                else:
                    total_price = purchase_qty_regular * unit_price
                    future_stock_levels[item['Item_Code']] += purchase_qty_regular
                future_data.append([
                    'purchase',
                    current_date.strftime('%d-%b-%y'),
                    'Vendor',
                    item['Item_Code'],
                    item['Brand'],
                    purchase_qty_summer if current_date.month in [2, 3, 4, 5] else purchase_qty_regular,
                    unit_price,
                    total_price,
                    future_stock_levels[item['Item_Code']]
                ])
        current_date += timedelta(days=1)
    
    df_future = pd.DataFrame(future_data, columns=['Transaction', 'Date', 'Customer', 'Item_Code', 'Brand', 'Qty', 'Unit_Price', 'Total_Price', 'Stock_Remaining'])
    
    # Filter for warnings
    future_warnings = df_future[(df_future['Stock_Remaining'] <= 100) & (df_future['Stock_Remaining'] >= 0)]
    
    # Add color-coded warning levels
    def get_warning_level(stock_remaining):
        if stock_remaining <= 10:
            return 'Dark Red'
        elif stock_remaining <= 25:
            return 'Light Red'
        elif stock_remaining <= 50:
            return 'Orange'
        elif stock_remaining <= 100:
            return 'Yellow'
        else:
            return 'None'

    future_warnings['Warning_Level'] = future_warnings['Stock_Remaining'].apply(get_warning_level)
    
    return future_warnings

# Predict stock warnings for the next year
future_start_date = datetime(2025, 1, 1)
future_end_date = datetime(2025, 12, 31)
future_warnings = predict_stock_warnings(future_start_date, future_end_date)

# Select relevant columns for the warnings and add remaining inventory column
future_warnings_details = future_warnings[['Date', 'Item_Code', 'Brand', 'Stock_Remaining', 'Warning_Level']]

# Remove duplicate records
future_warnings_details = future_warnings_details.drop_duplicates()

# Save the predicted warnings details to a CSV file
future_warnings_csv_path = 'predicted_stock_warnings.csv'
future_warnings_details.to_csv(future_warnings_csv_path, index=False)

print("Predicted future stock warnings details saved to:", future_warnings_csv_path)
# Out:
# Predicted future stock warnings details saved to: predicted_stock_warnings.csv
# C:\Users\Sharvesh\AppData\Local\Temp\ipykernel_28160\3546950632.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   future_warnings['Warning_Level'] = future_warnings['Stock_Remaining'].apply(get_warning_level)

# %%
import pandas as pd

# Load the predicted stock warnings from the CSV file
future_warnings_csv_path = 'predicted_stock_warnings.csv'
future_warnings_details = pd.read_csv(future_warnings_csv_path)

# Define color mapping
color_mapping = {
    'Dark Red': '#8B0000',
    'Light Red': '#FF6347',
    'Orange': '#FFA500',
    'Yellow': '#FFFF00'
}

# Start HTML string
html_string = '''
<html>
<head>
    <title>Predicted Stock Warnings</title>
    <style>
        table {{
            width: 100%;
            border-collapse: collapse;
        }}
        th, td {{
            border: 1px solid black;
            padding: 8px;
            text-align: left;
        }}
        th {{
            background-color: #f2f2f2;
        }}
    </style>
</head>
<body>
    <h2>Predicted Stock Warnings</h2>
    <table>
        <tr>
            <th>Date</th>
            <th>Item Code</th>
            <th>Brand</th>
            <th>Stock Remaining</th>
            <th>Warning Level</th>
        </tr>
'''

# Add table rows
for index, row in future_warnings_details.iterrows():
    color = color_mapping.get(row['Warning_Level'], 'white')
    html_string += f'''
        <tr style="background-color: {color}">
            <td>{row['Date']}</td>
            <td>{row['Item_Code']}</td>
            <td>{row['Brand']}</td>
            <td>{row['Stock_Remaining']}</td>
            <td>{row['Warning_Level']}</td>
        </tr>
    '''

# End HTML string
html_string += '''
    </table>
</body>
</html>
'''

# Save HTML string to file
html_file_path = 'predicted_stock_warnings.html'
with open(html_file_path, 'w') as file:
    file.write(html_string)

print("HTML file generated and saved to:", html_file_path)
# Out:
# HTML file generated and saved to: predicted_stock_warnings.html

# %%
import pandas as pd

# Load the predicted stock warnings from the CSV file
future_warnings_csv_path = 'predicted_stock_warnings.csv'
future_warnings_details = pd.read_csv(future_warnings_csv_path)

# Define color mapping for warning levels
def get_warning_color(stock_remaining):
    if stock_remaining == 0:
        return 'critical'
    elif stock_remaining <= 10:
        return 'dark-red'
    elif stock_remaining <= 25:
        return 'light-red'
    elif stock_remaining <= 50:
        return 'orange'
    elif stock_remaining <= 100:
        return 'yellow'
    else:
        return 'none'

# Add a column for warning level based on stock remaining
future_warnings_details['Warning_Level'] = future_warnings_details['Stock_Remaining'].apply(get_warning_color)

# Start HTML string with a button and legend
html_string = '''
<html>
<head>
    <title>Predicted Stock Warnings</title>
    <style>
        body {
            display: flex;
            justify-content: center;
            align-items: center;
            flex-direction: column;
            font-family: Arial, sans-serif;
        }
        table {
            width: 80%;
            border-collapse: collapse;
            margin-top: 20px;
        }
        th, td {
            border: 1px solid black;
            padding: 8px;
            text-align: left;
        }
        th {
            background-color: #f2f2f2;
        }
        .critical {
            background-color: black;
            color: white;
        }
        .dark-red {
            background-color: #8B0000;
            color: white;
        }
        .light-red {
            background-color: #FF6347;
            color: white;
        }
        .orange {
            background-color: #FFA500;
            color: black;
        }
        .yellow {
            background-color: #FFFF00;
            color: black;
        }
        .legend {
            display: flex;
            flex-direction: column;
            align-items: center;
            margin-bottom: 20px;
        }
        .legend div {
            display: flex;
            align-items: center;
            margin-bottom: 5px;
        }
        .color-box {
            width: 20px;
            height: 20px;
            margin-right: 10px;
        }
    </style>
    <script>
        function generatePredictions() {
            document.getElementById('predictionsTable').style.display = 'table';
        }
    </script>
</head>
<body>
    <h2>Predicted Stock Warnings</h2>
    <button onclick="generatePredictions()">Generate Predictions</button>
    <div class="legend">
        <div><div class="color-box yellow"></div>Warning Level 1: Stock ≤ 100</div>
        <div><div class="color-box orange"></div>Warning Level 2: Stock ≤ 50</div>
        <div><div class="color-box light-red"></div>Warning Level 3: Stock ≤ 25</div>
        <div><div class="color-box dark-red"></div>Warning Level 4: Stock ≤ 10</div>
        <div><div class="color-box critical"></div>Critical Warning: Stock = 0</div>
    </div>
    <table id="predictionsTable" style="display: none;">
        <tr>
            <th>Date</th>
            <th>Item Code</th>
            <th>Brand</th>
            <th>Stock Remaining</th>
            <th>Warning Level</th>
        </tr>
'''

# Add table rows
for index, row in future_warnings_details.iterrows():
    warning_class = row['Warning_Level']
    
    html_string += f'''
        <tr>
            <td>{row['Date']}</td>
            <td>{row['Item_Code']}</td>
            <td>{row['Brand']}</td>
            <td>{row['Stock_Remaining']}</td>
            <td class="{warning_class}"></td>
        </tr>
    '''

# End HTML string
html_string += '''
    </table>
</body>
</html>
'''

# Save HTML string to file with UTF-8 encoding
html_file_path = 'predicted_stock_warnings.html'
with open(html_file_path, 'w', encoding='utf-8') as file:
    file.write(html_string)

print("HTML file generated and saved to:", html_file_path)
# Out:
# HTML file generated and saved to: predicted_stock_warnings.html
